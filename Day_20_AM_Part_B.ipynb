# %% [markdown]
# <a href="https://colab.research.google.com/github/hiten4/Day20AM/blob/main/Day_20_AM_Part_B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Vector:
    def __init__(self, values):
        self.values = values

    def __add__(self, other):
        result = []
        for i in range(len(self.values)):
            result.append(self.values[i] + other.values[i])
        return Vector(tuple(result))

    def __sub__(self, other):
        result = []
        for i in range(len(self.values)):
            result.append(self.values[i] - other.values[i])
        return Vector(tuple(result))

    def __mul__(self, scalar):
        result = []
        for i in range(len(self.values)):
            result.append(self.values[i] * scalar)
        return Vector(tuple(result))

    def __repr__(self):
        return f"Vector{self.values}"

# %%
v1 = Vector((1, 2, 3))
v2 = Vector((4, 5, 6))

print("Addition:", v1 + v2)
print("Subtraction:", v1 - v2)
print("Scalar Multiplication:", v1 * 3)
# Out:
# Addition: Vector(5, 7, 9)
# Subtraction: Vector(-3, -3, -3)
# Scalar Multiplication: Vector(3, 6, 9)
